# %%
import json,csv
import pandas as pd
import glob

# 年月列追加-2014

# 201401
df_ym = pd.read_csv('data\\raw\\opendata01_h26_01c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 1

df_ym.to_csv("201401.csv")

# 201402
df_ym = pd.read_csv('data\\raw\\opendata01_h26_02c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 2

df_ym.to_csv("201402.csv")

# 201403
df_ym = pd.read_csv('data\\raw\\opendata01_h26_03c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 3

df_ym.to_csv("201403.csv")

# 201404
df_ym = pd.read_csv('data\\raw\\opendata01_h26_04c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 4

df_ym.to_csv("201404.csv")

# 201405
df_ym = pd.read_csv('data\\raw\\opendata01_h26_05c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 5

df_ym.to_csv("201405.csv")

# 201406
df_ym = pd.read_csv('data\\raw\\opendata01_h26_06c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 6

df_ym.to_csv("201406.csv")

# 201407
df_ym = pd.read_csv('data\\raw\\opendata01_h26_07c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 7

df_ym.to_csv("201407.csv")

# 201408
df_ym = pd.read_csv('data\\raw\\opendata01_h26_08c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 8

df_ym.to_csv("201408.csv")

# 201409
df_ym = pd.read_csv('data\\raw\\opendata01_h26_09c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 9

df_ym.to_csv("201409.csv")

# 201410
df_ym = pd.read_csv('data\\raw\\opendata01_h26_10c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 10

df_ym.to_csv("201410.csv")

# 201411
df_ym = pd.read_csv('data\\raw\\opendata01_h26_11c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 11

df_ym.to_csv("201411.csv")

# 201412
df_ym = pd.read_csv('data\\raw\\opendata01_h26_12c.csv', encoding="shift-jis")
df_ym['year'] = 2014
df_ym['month'] = 12

df_ym.to_csv("201412.csv")

# %%
# 年月列追加-2015

# 201501
df_ym = pd.read_csv('data\\raw\\opendata01_h27_01c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 1

df_ym.to_csv("201501.csv")

# 201502
df_ym = pd.read_csv('data\\raw\\opendata01_h27_02c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 2

df_ym.to_csv("201502.csv")

# 201503
df_ym = pd.read_csv('data\\raw\\opendata01_h27_03c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 3

df_ym.to_csv("201503.csv")

# 201504
df_ym = pd.read_csv('data\\raw\\opendata01_h27_04c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 4

df_ym.to_csv("201504.csv")

# 201505
df_ym = pd.read_csv('data\\raw\\opendata01_h27_05c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 5

df_ym.to_csv("201505.csv")

# 201506
df_ym = pd.read_csv('data\\raw\\opendata01_h27_06c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 6

df_ym.to_csv("201506.csv")

# 201507
df_ym = pd.read_csv('data\\raw\\opendata01_h27_07c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 7

df_ym.to_csv("201507.csv")

# 201508
df_ym = pd.read_csv('data\\raw\\opendata01_h27_08c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 8

df_ym.to_csv("201508.csv")

# 201509
df_ym = pd.read_csv('data\\raw\\opendata01_h27_09c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 9

df_ym.to_csv("201509.csv")

# 201510
df_ym = pd.read_csv('data\\raw\\opendata01_h27_10c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 10

df_ym.to_csv("201510.csv")

# 201511
df_ym = pd.read_csv('data\\raw\\opendata01_h27_11c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 11

df_ym.to_csv("201511.csv")

# 201512
df_ym = pd.read_csv('data\\raw\\opendata01_h27_12c.csv', encoding="shift-jis")
df_ym['year'] = 2015
df_ym['month'] = 12

df_ym.to_csv("201512.csv")

# %%
# 年月列追加-2016

# 201601
df_ym = pd.read_csv('data\\raw\\opendata01_h28_01c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 1

df_ym.to_csv("201601.csv")

# 201602
df_ym = pd.read_csv('data\\raw\\opendata01_h28_02c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 2

df_ym.to_csv("201602.csv")

# 201603
df_ym = pd.read_csv('data\\raw\\opendata01_h28_03c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 3

df_ym.to_csv("201603.csv")

# 201604
df_ym = pd.read_csv('data\\raw\\opendata01_h28_04c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 4

df_ym.to_csv("201604.csv")

# 201605
df_ym = pd.read_csv('data\\raw\\opendata01_h28_05c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 5

df_ym.to_csv("201605.csv")

# 201606
df_ym = pd.read_csv('data\\raw\\opendata01_h28_06c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 6

df_ym.to_csv("201606.csv")

# 201607
df_ym = pd.read_csv('data\\raw\\opendata01_h28_07c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 7

df_ym.to_csv("201607.csv")

# 201608
df_ym = pd.read_csv('data\\raw\\opendata01_h28_08c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 8

df_ym.to_csv("201608.csv")

# 201609
df_ym = pd.read_csv('data\\raw\\opendata01_h28_09c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 9

df_ym.to_csv("201609.csv")

# 201610
df_ym = pd.read_csv('data\\raw\\opendata01_h28_10c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 10

df_ym.to_csv("201610.csv")

# 201611
df_ym = pd.read_csv('data\\raw\\opendata01_h28_11c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 11

df_ym.to_csv("201611.csv")

# 201612
df_ym = pd.read_csv('data\\raw\\opendata01_h28_12c.csv', encoding="shift-jis")
df_ym['year'] = 2016
df_ym['month'] = 12

df_ym.to_csv("201612.csv")

# %%
# 年月列追加-2017

# 201701
df_ym = pd.read_csv('data\\raw\\opendata01_h29_01c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 1

df_ym.to_csv("201701.csv")

# 201702
df_ym = pd.read_csv('data\\raw\\opendata01_h29_02c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 2

df_ym.to_csv("201702.csv")

# 201703
df_ym = pd.read_csv('data\\raw\\opendata01_h29_03c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 3

df_ym.to_csv("201703.csv")

# 201704
df_ym = pd.read_csv('data\\raw\\opendata01_h29_04c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 4

df_ym.to_csv("201704.csv")

# 201705
df_ym = pd.read_csv('data\\raw\\opendata01_h29_05c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 5

df_ym.to_csv("201705.csv")

# 201706
df_ym = pd.read_csv('data\\raw\\opendata01_h29_06c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 6

df_ym.to_csv("201706.csv")

# 201707
df_ym = pd.read_csv('data\\raw\\opendata01_h29_07c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 7

df_ym.to_csv("201707.csv")

# 201708
df_ym = pd.read_csv('data\\raw\\opendata01_h29_08c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 8

df_ym.to_csv("201708.csv")

# 201709
df_ym = pd.read_csv('data\\raw\\opendata01_h29_09c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 9

df_ym.to_csv("201709.csv")

# 201710
df_ym = pd.read_csv('data\\raw\\opendata01_h29_10c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 10

df_ym.to_csv("201710.csv")

# 201711
df_ym = pd.read_csv('data\\raw\\opendata01_h29_11c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 11

df_ym.to_csv("201711.csv")

# 201712
df_ym = pd.read_csv('data\\raw\\opendata01_h29_12c.csv', encoding="shift-jis")
df_ym['year'] = 2017
df_ym['month'] = 12

df_ym.to_csv("201712.csv")

# %%
# 年月列追加-2018

# 201801
df_ym = pd.read_csv('data\\raw\\opendata01_h30_01c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 1

df_ym.to_csv("201801.csv")

# 201802
df_ym = pd.read_csv('data\\raw\\opendata01_h30_02c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 2

df_ym.to_csv("201802.csv")

# 201803
df_ym = pd.read_csv('data\\raw\\opendata01_h30_03c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 3

df_ym.to_csv("201803.csv")

# 201804
df_ym = pd.read_csv('data\\raw\\opendata01_h30_04c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 4

df_ym.to_csv("201804.csv")

# 201805
df_ym = pd.read_csv('data\\raw\\opendata01_h30_05c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 5

df_ym.to_csv("201805.csv")

# 201806
df_ym = pd.read_csv('data\\raw\\opendata01_h30_06c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 6

df_ym.to_csv("201806.csv")

# 201807
df_ym = pd.read_csv('data\\raw\\opendata01_h30_07c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 7

df_ym.to_csv("201807.csv")

# 201808
df_ym = pd.read_csv('data\\raw\\opendata01_h30_08c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 8

df_ym.to_csv("201808.csv")

# 201809
df_ym = pd.read_csv('data\\raw\\opendata01_h30_09c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 9

df_ym.to_csv("201809.csv")

# 201810
df_ym = pd.read_csv('data\\raw\\opendata01_h30_10c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 10

df_ym.to_csv("201810.csv")

# 201811
df_ym = pd.read_csv('data\\raw\\opendata01_h30_11c.csv', encoding="shift-jis")
df_ym['year'] = 2018
df_ym['month'] = 11

df_ym.to_csv("201811.csv")

# %%
# ファイル結合（年単位）
csv_files = glob.glob('data\\raw_ym\\*.csv')
list = []

for f in csv_files:
    list.append(pd.read_csv(f, index_col=["KEY_CODE", "year","month"], encoding="utf-8"))
    
df_output = pd.concat(list)
df_output.drop('Unnamed: 0', axis=1, inplace=True)
df_output.to_csv("crime-db.csv")
